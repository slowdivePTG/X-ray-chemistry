# %%
import numpy as np
from species import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
def initial(txt1,txt2):
    test1=np.loadtxt(txt1)[-1]
    test2=np.loadtxt(txt2)[-1]
    data1 = open('Name')
    Name = []
    while 1:
        line = data1.readline()
        if not line:
            break
        line=line.strip('\n')
        temp='krome_idx_'+line.upper()
        if (temp[-1]=='J'):
            temp=temp[0:-1]+'j'
        Name.append(temp)
    species_list=[]
    for name in Name:
        species_list.append(name)
    return(test1,test2,Name,species_list)

# %%
def log_dev(a,b,zeta1,zeta2):
    y=np.log(a)-np.log(b)
    x=np.log(zeta1)-np.log(zeta2)
    return(y/x)

# %%
def alpha(test1,test2,Name,species_list,zeta1,zeta2):
    list_elementd = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        list_elementd.update(temp_dic)

    dict_out = sorted(list_elementd.items(), key = lambda item:item[1])
    gap = -0.375
    print('<',gap)
    for i in dict_out:
        if i[1] > gap:
            while (gap) < i[1]:
                gap += 0.25
            print ('<',gap)
        print(i)

# %%
test1,test2,Name,species_list = initial('case1','case1_1')
alpha(test1,test2,Name,species_list,6.8e-18,7.8e-18)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.5143019572076974)
# < -0.125
# ('krome_idx_NH3', -0.1976746169349235)
# < 0.125
# ('krome_idx_MG', -0.07507905216538832)
# ('krome_idx_N2', -0.05888868005724215)
# ('krome_idx_O2', -0.03245620692906889)
# ('krome_idx_CO', -0.03158124537490011)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_O', 0.02924528838495232)
# ('krome_idx_H2O', 0.03730309584683373)
# < 0.375
# ('krome_idx_HCN', 0.22875792549375998)
# ('krome_idx_N', 0.2705977168379882)
# ('krome_idx_MGj', 0.3471312606417483)
# ('krome_idx_E', 0.3488056251815923)
# < 0.625
# ('krome_idx_NO', 0.41835671240722067)
# ('krome_idx_HCO', 0.4544813423341358)
# ('krome_idx_HCOj', 0.6031330507984018)
# ('krome_idx_O2j', 0.6053316114208692)
# ('krome_idx_H3Oj', 0.609124135217549)
# ('krome_idx_HNOj', 0.6217161508163215)
# < 0.875
# ('krome_idx_HCNHj', 0.7404235413072462)
# ('krome_idx_N2Hj', 0.7527494414800818)
# ('krome_idx_NH3j', 0.7685781634809706)
# < 1.125
# ('krome_idx_OH', 0.8797298063205911)
# ('krome_idx_NH2', 0.8913401008319599)
# ('krome_idx_CH2', 0.8980200864085178)
# ('krome_idx_C', 0.9403895455565395)
# ('krome_idx_H3j', 0.9491443904681985)
# ('krome_idx_Hj', 0.9587713567572919)
# ('krome_idx_COj', 0.9662918656861562)
# ('krome_idx_N2j', 0.9680175985506546)
# ('krome_idx_Nj', 0.9721148440953971)
# ('krome_idx_OHj', 0.9788550322189229)
# ('krome_idx_H2Oj', 0.9797018152442802)
# ('krome_idx_NH2j', 0.9823954075543918)
# ('krome_idx_NHj', 0.9842322124781177)
# ('krome_idx_Oj', 0.9879651839007093)
# ('krome_idx_H', 0.9911505815321447)
# ('krome_idx_H2j', 1.0000593947728544)
# ('krome_idx_HEj', 1.0266648639669345)
# ('krome_idx_Cj', 1.0274064183626557)
# ('krome_idx_NH', 1.0441870224718603)
# < 1.375
# ('krome_idx_CH', 1.1612077364999562)
# ('krome_idx_HCNj', 1.1929057962119851)
# ('krome_idx_CN', 1.2833299315522777)
# ('krome_idx_CH3j', 1.314463907530384)
# < 1.625
# ('krome_idx_CH2j', 1.6064345635288573)
# < 1.875
# ('krome_idx_CHj', 1.662458774987809)
# ('krome_idx_C2H2j', 1.6747016392931358)
# < 2.375
# ('krome_idx_C2', 2.2765914516244683)
# ('krome_idx_C2Hj', 2.306315096760076)
# < 2.875
# ('krome_idx_C2j', 2.844410409191712)

# %%
test1,test2,Name,species_list = initial('case2','case2_1')
alpha(test1,test2,Name,species_list,6.8e-16,7.8e-16)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.8438600000834124)
# < -0.125
# ('krome_idx_MG', -0.28847720895795115)
# ('krome_idx_NH3', -0.15313604641889852)
# < 0.125
# ('krome_idx_O2', -0.08975127158189908)
# ('krome_idx_N2', -0.03418307729876373)
# ('krome_idx_HCO', -0.032429335222182845)
# ('krome_idx_H2', -0.009865837167401732)
# ('krome_idx_HE', -0.0)
# ('krome_idx_CO', -0.0)
# ('krome_idx_H2O', 0.05361303154819855)
# ('krome_idx_O', 0.09565680195921736)
# < 0.375
# ('krome_idx_MGj', 0.27212410241218354)
# ('krome_idx_E', 0.2764981535183222)
# ('krome_idx_N', 0.3725667457292559)
# < 0.625
# ('krome_idx_HCN', 0.4994602609089436)
# ('krome_idx_NO', 0.5732914504273059)
# ('krome_idx_HCOj', 0.6144280249683669)
# < 0.875
# ('krome_idx_O2j', 0.6432320984450002)
# ('krome_idx_N2Hj', 0.6731533860873768)
# ('krome_idx_H3Oj', 0.7054419268747822)
# ('krome_idx_CH', 0.8198212897532179)
# ('krome_idx_NH3j', 0.8345563663738446)
# ('krome_idx_OH', 0.8390888596602866)
# ('krome_idx_NH', 0.8471519864827932)
# < 1.125
# ('krome_idx_H3j', 0.8860061634893702)
# ('krome_idx_NH2', 0.9294764375390023)
# ('krome_idx_CH2', 0.9421526818713537)
# ('krome_idx_Oj', 0.9769920531496794)
# ('krome_idx_N2j', 0.9839496165287894)
# ('krome_idx_OHj', 0.991982060693271)
# ('krome_idx_COj', 0.9994883063801345)
# ('krome_idx_H2j', 0.9999009262944246)
# ('krome_idx_H2Oj', 1.0056210811719517)
# ('krome_idx_HEj', 1.0083391115463196)
# ('krome_idx_Hj', 1.0117636103088887)
# ('krome_idx_Nj', 1.0148098194650594)
# ('krome_idx_C', 1.0214621374378485)
# ('krome_idx_NHj', 1.027243652150219)
# ('krome_idx_H', 1.0296226566222046)
# ('krome_idx_NH2j', 1.0671243109577424)
# ('krome_idx_Cj', 1.07044601189007)
# ('krome_idx_CH3j', 1.0724508997000755)
# < 1.375
# ('krome_idx_HCNHj', 1.1357273113511641)
# ('krome_idx_HNOj', 1.2134037422366053)
# ('krome_idx_CN', 1.2972863376330823)
# ('krome_idx_CH2j', 1.3442618515182965)
# < 1.875
# ('krome_idx_C2H2j', 1.6270569809202093)
# ('krome_idx_HCNj', 1.6927325109959241)
# ('krome_idx_C2', 1.7960129677063363)
# ('krome_idx_CHj', 1.8477738192027666)
# < 2.125
# ('krome_idx_C2j', 1.901292475690096)
# ('krome_idx_C2Hj', 1.9015469618817573)

# %%
test1,test2,Name,species_list = initial('case3','case3_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.44003812337080844)
# < 0.125
# ('krome_idx_NH3', -0.1197080834664221)
# ('krome_idx_MG', -0.06026965188947127)
# ('krome_idx_O2', -0.04944845281706075)
# ('krome_idx_N2', -0.006272542318347077)
# ('krome_idx_H2', -0.004408041022257235)
# ('krome_idx_HE', -0.0)
# ('krome_idx_CO', 0.0024830339343150437)
# ('krome_idx_HCN', 0.06090487206948074)
# ('krome_idx_O', 0.063675845854622)
# ('krome_idx_H2O', 0.09950050553347864)
# < 0.375
# ('krome_idx_N', 0.25091981391955887)
# ('krome_idx_MGj', 0.34039550771408883)
# ('krome_idx_E', 0.3408998533938605)
# < 0.625
# ('krome_idx_HCO', 0.48299176118334214)
# ('krome_idx_HCNHj', 0.580379937495188)
# ('krome_idx_HCOj', 0.6148294969115722)
# < 0.875
# ('krome_idx_O2j', 0.6375043248124294)
# ('krome_idx_H3Oj', 0.6616811084433185)
# ('krome_idx_CH3j', 0.7961959963800882)
# ('krome_idx_NH3j', 0.8170641365726463)
# ('krome_idx_N2Hj', 0.8173250785735985)
# ('krome_idx_C2H2j', 0.8419791683171003)
# < 1.125
# ('krome_idx_NO', 0.8766241387996272)
# ('krome_idx_NH2', 0.8816675810313422)
# ('krome_idx_OH', 0.9124071331470617)
# ('krome_idx_CH', 0.9357868958626399)
# ('krome_idx_H3j', 0.9447338167079824)
# ('krome_idx_CH2', 0.998912635470105)
# ('krome_idx_COj', 1.0001137468233472)
# ('krome_idx_N2j', 1.001204262810381)
# ('krome_idx_H2j', 1.0023066440156696)
# ('krome_idx_HEj', 1.002813000146065)
# ('krome_idx_NH2j', 1.009811287670034)
# ('krome_idx_Nj', 1.0110384053394266)
# ('krome_idx_NHj', 1.0112396466407807)
# ('krome_idx_OHj', 1.01387925488518)
# ('krome_idx_Oj', 1.0146864501896675)
# ('krome_idx_H2Oj', 1.0212359123450077)
# ('krome_idx_Hj', 1.025799154297398)
# ('krome_idx_H', 1.028709742746829)
# ('krome_idx_C', 1.0403344679087556)
# ('krome_idx_Cj', 1.0441335016032782)
# ('krome_idx_HCNj', 1.082390999075946)
# ('krome_idx_CH2j', 1.0870317059269732)
# ('krome_idx_NH', 1.0887607752678665)
# < 1.375
# ('krome_idx_CN', 1.160205799428446)
# ('krome_idx_C2', 1.194837607614109)
# < 1.625
# ('krome_idx_HNOj', 1.5107350899360328)
# < 1.875
# ('krome_idx_CHj', 1.757383480531183)
# ('krome_idx_C2Hj', 1.8510839520115738)
# < 2.125
# ('krome_idx_C2j', 1.9475140606498182)

# %%
test1,test2,Name,species_list = initial('case4','case4_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.918426189103565)
# ('krome_idx_MG', -0.4374936609274173)
# < -0.125
# ('krome_idx_HCO', -0.17379668814791746)
# ('krome_idx_O2', -0.17025201128803308)
# ('krome_idx_NH3', -0.13985642081731206)
# < 0.125
# ('krome_idx_H2', -0.08752772326440536)
# ('krome_idx_N2', -0.05980052459966793)
# ('krome_idx_CO', -0.0016493203996581684)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2O', 0.05063693073419798)
# ('krome_idx_O', 0.09255656169552662)
# < 0.375
# ('krome_idx_E', 0.2188392881480758)
# ('krome_idx_MGj', 0.25250440796535123)
# < 0.625
# ('krome_idx_NO', 0.42451877498035656)
# ('krome_idx_N', 0.4459580268198209)
# ('krome_idx_O2j', 0.6126625590691094)
# < 0.875
# ('krome_idx_HCN', 0.6529433924527075)
# ('krome_idx_N2Hj', 0.6682512401609931)
# ('krome_idx_HCOj', 0.6768513599541767)
# ('krome_idx_H3Oj', 0.7823898698857229)
# ('krome_idx_NH', 0.7876271605328893)
# ('krome_idx_CH', 0.8033049942564321)
# ('krome_idx_OH', 0.8498412087673972)
# < 1.125
# ('krome_idx_H3j', 0.8785271929688416)
# ('krome_idx_NH3j', 0.9330109907088591)
# ('krome_idx_NH2', 0.9859245707457982)
# ('krome_idx_HEj', 0.9903761709063853)
# ('krome_idx_Hj', 0.9950024461711058)
# ('krome_idx_H', 1.0108025754315613)
# ('krome_idx_N2j', 1.018925328277126)
# ('krome_idx_CH2', 1.0324841777844505)
# ('krome_idx_H2j', 1.0604199891733053)
# ('krome_idx_OHj', 1.0872785336910793)
# ('krome_idx_Cj', 1.0960979161702271)
# ('krome_idx_H2Oj', 1.1015321769802386)
# ('krome_idx_COj', 1.1022795605360451)
# ('krome_idx_HNOj', 1.1039858366150084)
# ('krome_idx_Oj', 1.1228219207085557)
# < 1.375
# ('krome_idx_Nj', 1.1301619589842598)
# ('krome_idx_NHj', 1.1625165942407554)
# ('krome_idx_C', 1.1853778954206748)
# ('krome_idx_NH2j', 1.200262699221391)
# ('krome_idx_CN', 1.368160662837488)
# ('krome_idx_HCNHj', 1.3719671031908358)
# < 1.625
# ('krome_idx_CH3j', 1.4015896316533045)
# < 1.875
# ('krome_idx_CH2j', 1.6969020331420124)
# ('krome_idx_C2H2j', 1.7133047582286118)
# ('krome_idx_HCNj', 1.85389007373033)
# ('krome_idx_C2', 1.8576500209890752)
# < 2.125
# ('krome_idx_C2j', 1.9931503761007985)
# ('krome_idx_C2Hj', 1.9999111058265477)
# ('krome_idx_CHj', 2.0544832058294404)

# %%
test1,test2,Name,species_list = initial('case5','case5_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_MG', -0.5830452065479488)
# < -0.125
# ('krome_idx_HCO', -0.28022310412913537)
# ('krome_idx_N2', -0.16230427214629992)
# < 0.125
# ('krome_idx_O2', -0.05637147316151857)
# ('krome_idx_CO', -0.02473498039513255)
# ('krome_idx_H2', -0.0005487723445750133)
# ('krome_idx_HE', -0.0)
# ('krome_idx_O', 0.040998157676216694)
# ('krome_idx_MGj', 0.06896777361253943)
# < 0.375
# ('krome_idx_E', 0.14964639021588516)
# ('krome_idx_H2O', 0.2252370250439968)
# ('krome_idx_CO2', 0.30618230736273017)
# ('krome_idx_NH3', 0.3130035515073011)
# ('krome_idx_NO', 0.32144955680299114)
# ('krome_idx_N', 0.34010674940821567)
# < 0.625
# ('krome_idx_O2j', 0.5219732990635632)
# ('krome_idx_CH', 0.533766162689764)
# ('krome_idx_N2Hj', 0.5933896428127492)
# < 0.875
# ('krome_idx_NH', 0.63794446231657)
# ('krome_idx_CH2', 0.6677147647079554)
# ('krome_idx_Hj', 0.6931508271484506)
# ('krome_idx_HCOj', 0.7113077311106774)
# ('krome_idx_N2j', 0.7867546573266178)
# ('krome_idx_HCN', 0.8057894101219104)
# ('krome_idx_OH', 0.8061555731284206)
# ('krome_idx_Cj', 0.8159067757148757)
# < 1.125
# ('krome_idx_H3j', 0.8800053833628418)
# ('krome_idx_H3Oj', 0.8862072990199341)
# ('krome_idx_COj', 0.9230449791887086)
# ('krome_idx_HEj', 0.9476574046496794)
# ('krome_idx_H2j', 0.9721150849737)
# ('krome_idx_C', 0.9756618005509853)
# ('krome_idx_OHj', 0.9779718201184019)
# ('krome_idx_Oj', 0.9783411980847536)
# ('krome_idx_H', 0.9891930042313407)
# ('krome_idx_H2Oj', 1.0305561511618373)
# ('krome_idx_Nj', 1.0429093139420125)
# ('krome_idx_CN', 1.0462136880732826)
# ('krome_idx_NH2', 1.0497500503410815)
# ('krome_idx_HNOj', 1.0572638492663449)
# ('krome_idx_NH3j', 1.0662075165740443)
# ('krome_idx_NHj', 1.0938733026329441)
# < 1.375
# ('krome_idx_NH2j', 1.1888236817207005)
# ('krome_idx_C2H2j', 1.3545002362518062)
# < 1.625
# ('krome_idx_C2j', 1.383931151480227)
# ('krome_idx_C2Hj', 1.429486115017075)
# ('krome_idx_C2', 1.4602945056129122)
# ('krome_idx_CH3j', 1.4850678823517043)
# ('krome_idx_HCNHj', 1.493927102746551)
# < 1.875
# ('krome_idx_CH2j', 1.6335902126691677)
# ('krome_idx_HCNj', 1.6595331654620915)
# ('krome_idx_CHj', 1.748110014796433)

# %%
import matplotlib.pyplot as plt 
def alpha_range(krolik_table,txt1,txt2,zeta1,zeta2):
    test1,test2,Name,species_list = initial(txt1,txt2)
    user_alpha = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        user_alpha.update(temp_dic)
    krolik_range = {}
    data1 = open(krolik_table)
    title = ''
    while 1:
        line = data1.readline()
        if not line:
            break
        if line[0]=='#':
            title = line[1:-1]
            continue
        line = line.strip('\n').upper()
        line = line.replace('+','j')
        alpha = float(line[0:line.find(' ')])
        temp = line[line.find(' '):-1]
        temp = temp.replace(' ','')
        temp_list = temp.split(',')
        for i in temp_list:
            temp_dic = {i:alpha}
            krolik_range.update(temp_dic)
    me = [] # Store my calculation
    krolik = [] #Store the range of alpha
    names = []
    for key in krolik_range:
        temp = 'krome_idx_'+key
        me.append(user_alpha[temp]) #My Calculation
        krolik.append(krolik_range[key]) #Krolik's Results
        names.append(key.replace('j','+'))
    me, krolik = np.array(me), np.array(krolik)
    i = np.arange(len(krolik_range))
    plt.figure(figsize=(30,15))
    plt.title(title,fontsize=30)
    plt.fill_between(i, krolik, krolik+0.25, alpha=0.5, edgecolor='#89916B', facecolor='#B5CAA0')
    for j in range(len(me)):
        col = '#CC543A' #Color of the dot
        if ((krolik[j]-0.25<me[j]) and (me[j]<krolik[j]+0.50)):
            col = '#86A697'
        else:
            plt.text(i[j]-0.15*(len(names[j])-1),me[j]-0.125,names[j],fontsize=15)
        plt.scatter(i[j],me[j],color=col)
    plt.xticks(i, names,fontsize=20, rotation=60)
    plt.yticks(fontsize=30)
    plt.ylabel(r'$\alpha$',fontsize=30)
    plt.savefig(krolik_table+'.png')
    plt.show()

# %%
# Cosmic Ray 6.8e-18
alpha_range('Table1','case1','case1_1',6.8e-18,7.8e-18)

# %%
# Cosmic Ray 6.8e-16
alpha_range('Table2','case2','case2_1',6.8e-16,7.0e-16)

# %%
# X-ray Jx21=0.08
alpha_range('Table3','case3','case3_1',1,1.2)

# %%
# X-ray Jx21=8
alpha_range('Table4','case4','case4_1',1,1.2)

# %%
# X-ray Jx21=80
alpha_range('Table5','case5','case5_1',1,1.2)
