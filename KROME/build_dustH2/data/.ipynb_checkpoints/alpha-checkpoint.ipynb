# %%
import numpy as np
from species import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
def initial(txt1,txt2):
    test1=np.loadtxt(txt1)[-1]
    test2=np.loadtxt(txt2)[-1]
    data1 = open('Name')
    Name = []
    while 1:
        line = data1.readline()
        if not line:
            break
        line=line.strip('\n')
        temp='krome_idx_'+line.upper()
        if (temp[-1]=='J'):
            temp=temp[0:-1]+'j'
        Name.append(temp)
    species_list=[]
    for name in Name:
        species_list.append(name)
    return(test1,test2,Name,species_list)

# %%
def log_dev(a,b,zeta1,zeta2):
    y=np.log(a)-np.log(b)
    x=np.log(zeta1)-np.log(zeta2)
    return(y/x)

# %%
def alpha(test1,test2,Name,species_list,zeta1,zeta2):
    list_elementd = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        list_elementd.update(temp_dic)

    dict_out = sorted(list_elementd.items(), key = lambda item:item[1])
    gap = -0.375
    print('<',gap)
    for i in dict_out:
        if i[1] > gap:
            while (gap) < i[1]:
                gap += 0.25
            print ('<',gap)
        print(i)

# %%
test1,test2,Name,species_list = initial('case1','case1_1')
alpha(test1,test2,Name,species_list,6.8e-18,7.8e-18)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.41595394100563005)
# < 0.125
# ('krome_idx_NH3', -0.07755381835602294)
# ('krome_idx_MG', -0.045449845067241985)
# ('krome_idx_O2', -0.028196565873298544)
# ('krome_idx_N2', -0.004847274997973725)
# ('krome_idx_H2', -0.0043908813882754805)
# ('krome_idx_HE', -0.0)
# ('krome_idx_CO', 0.002660179305005127)
# ('krome_idx_O', 0.061364632851718594)
# ('krome_idx_HCN', 0.08079599830488944)
# ('krome_idx_H2O', 0.11601036808144181)
# < 0.375
# ('krome_idx_N', 0.24063465086664543)
# ('krome_idx_MGj', 0.3373559222025287)
# ('krome_idx_E', 0.33815769663258294)
# < 0.625
# ('krome_idx_HCO', 0.5103762459605057)
# ('krome_idx_HCNHj', 0.5924997363002926)
# ('krome_idx_HCOj', 0.6223551759544284)
# < 0.875
# ('krome_idx_C2H2j', 0.6372866067018536)
# ('krome_idx_O2j', 0.6503914255880474)
# ('krome_idx_H3Oj', 0.6591452498720214)
# ('krome_idx_CH3j', 0.7685154569007012)
# ('krome_idx_NH3j', 0.8377162111761554)
# ('krome_idx_N2Hj', 0.8426484190499067)
# ('krome_idx_C2', 0.8656405952739437)
# < 1.125
# ('krome_idx_NH2', 0.876348878199505)
# ('krome_idx_NO', 0.8974523269958856)
# ('krome_idx_OH', 0.9055157156281007)
# ('krome_idx_CH', 0.9449815303850229)
# ('krome_idx_H3j', 0.9509673895855445)
# ('krome_idx_CH2', 0.9729398827927759)
# ('krome_idx_C', 0.9925733993575104)
# ('krome_idx_Oj', 0.9930123953957001)
# ('krome_idx_COj', 0.9930535796196496)
# ('krome_idx_H2j', 1.000017335232819)
# ('krome_idx_NH2j', 1.001651930023263)
# ('krome_idx_N2j', 1.0016906422781584)
# ('krome_idx_HEj', 1.0022070811541854)
# ('krome_idx_Nj', 1.002783477313246)
# ('krome_idx_NHj', 1.002921701888732)
# ('krome_idx_OHj', 1.0110965311847224)
# ('krome_idx_H2Oj', 1.0150694891938103)
# ('krome_idx_Hj', 1.016182338629476)
# ('krome_idx_H', 1.0232524496541962)
# ('krome_idx_Cj', 1.0283830409084123)
# ('krome_idx_CH2j', 1.0459008446818148)
# ('krome_idx_HCNj', 1.076373482783326)
# ('krome_idx_NH', 1.1113022216867008)
# ('krome_idx_CN', 1.1147855423921473)
# < 1.625
# ('krome_idx_CHj', 1.4368506588064083)
# ('krome_idx_HNOj', 1.5229821683137936)
# < 1.875
# ('krome_idx_C2Hj', 1.8033236728814959)
# < 2.125
# ('krome_idx_C2j', 1.9035938390650335)

# %%
test1,test2,Name,species_list = initial('case2','case2_1')
alpha(test1,test2,Name,species_list,6.8e-16,7.8e-16)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.8423393264298425)
# < -0.125
# ('krome_idx_MG', -0.2867861730376221)
# ('krome_idx_NH3', -0.163844478591395)
# < 0.125
# ('krome_idx_O2', -0.09715853191405215)
# ('krome_idx_HCO', -0.039190788122371284)
# ('krome_idx_N2', -0.034186532765287214)
# ('krome_idx_H2', -0.020379716149260825)
# ('krome_idx_HE', -0.0)
# ('krome_idx_CO', 9.120688451967097e-05)
# ('krome_idx_H2O', 0.05291141068023784)
# ('krome_idx_O', 0.10259399696178184)
# < 0.375
# ('krome_idx_MGj', 0.27131410732589273)
# ('krome_idx_E', 0.2757332055405721)
# < 0.625
# ('krome_idx_N', 0.37667786228831224)
# ('krome_idx_HCN', 0.4878347204954583)
# ('krome_idx_NO', 0.5605835855039478)
# ('krome_idx_HCOj', 0.605642911308492)
# < 0.875
# ('krome_idx_O2j', 0.633684610867289)
# ('krome_idx_N2Hj', 0.6635010728103732)
# ('krome_idx_H3Oj', 0.7012841841449261)
# ('krome_idx_CH', 0.8090912998056634)
# ('krome_idx_OH', 0.8270556385469208)
# ('krome_idx_NH', 0.8310619836119388)
# ('krome_idx_NH3j', 0.8334408406704413)
# ('krome_idx_H3j', 0.8749711311312343)
# < 1.125
# ('krome_idx_NH2', 0.9188505516705241)
# ('krome_idx_CH2', 0.9330620758034898)
# ('krome_idx_Oj', 0.9855632953360336)
# ('krome_idx_N2j', 0.9963417974989347)
# ('krome_idx_OHj', 0.9990066587133779)
# ('krome_idx_H2j', 0.9999009262944246)
# ('krome_idx_Hj', 1.0078893468799877)
# ('krome_idx_HEj', 1.010018968942907)
# ('krome_idx_COj', 1.0104106129582817)
# ('krome_idx_H2Oj', 1.0120839698723862)
# ('krome_idx_H', 1.0208299659301476)
# ('krome_idx_C', 1.0212563033260411)
# ('krome_idx_Nj', 1.0257066279322744)
# ('krome_idx_NHj', 1.0376299329168364)
# ('krome_idx_CH3j', 1.0635266971413908)
# ('krome_idx_NH2j', 1.0746602232506202)
# ('krome_idx_Cj', 1.0791220542808024)
# ('krome_idx_HCNHj', 1.1206651358812005)
# < 1.375
# ('krome_idx_HNOj', 1.1909018059368457)
# ('krome_idx_CN', 1.284489550552617)
# ('krome_idx_CH2j', 1.3447533111089367)
# < 1.875
# ('krome_idx_C2H2j', 1.6254640342422488)
# ('krome_idx_HCNj', 1.6882876775854896)
# ('krome_idx_C2', 1.7857138478166732)
# ('krome_idx_CHj', 1.8482069792335238)
# < 2.125
# ('krome_idx_C2j', 1.9092695260305919)
# ('krome_idx_C2Hj', 1.9095341651532387)

# %%
test1,test2,Name,species_list = initial('case3','case3_1')
alpha(test1,test2,Name,species_list,8e-18,8e-18*1.1)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.6757704020039991)
# ('krome_idx_NH3', -0.3977121587959727)
# < -0.125
# ('krome_idx_HCN', -0.22104873825587704)
# ('krome_idx_O2', -0.17188257775903668)
# < 0.125
# ('krome_idx_MG', -0.08778917195070865)
# ('krome_idx_H2O', -0.082491676525603)
# ('krome_idx_N2', -0.011169867549998422)
# ('krome_idx_H2', -0.007823188864209307)
# ('krome_idx_HE', -0.0)
# ('krome_idx_CO', 0.0007880865316977839)
# ('krome_idx_O', 0.06894355735786743)
# < 0.375
# ('krome_idx_N', 0.29188648499770237)
# ('krome_idx_HCO', 0.36617074169407)
# < 0.625
# ('krome_idx_HCNHj', 0.3943676573030923)
# ('krome_idx_MGj', 0.4020521698542557)
# ('krome_idx_E', 0.40434723756556934)
# ('krome_idx_HCOj', 0.5297237660128714)
# ('krome_idx_O2j', 0.5739996459346529)
# ('krome_idx_H3Oj', 0.589387092198686)
# < 0.875
# ('krome_idx_NH3j', 0.717319589736332)
# ('krome_idx_N2Hj', 0.7610867487660246)
# ('krome_idx_NO', 0.8370719905004171)
# ('krome_idx_CH3j', 0.8421609963660711)
# < 1.125
# ('krome_idx_NH2', 0.8797378480454208)
# ('krome_idx_OH', 0.903206150434566)
# ('krome_idx_C2H2j', 0.9061253300055369)
# ('krome_idx_CH', 0.9070582081037482)
# ('krome_idx_H3j', 0.9302801227304003)
# ('krome_idx_HCNj', 0.9344152094092066)
# ('krome_idx_Oj', 1.0020541999353592)
# ('krome_idx_COj', 1.0047147489692905)
# ('krome_idx_H2j', 1.004750619043987)
# ('krome_idx_OHj', 1.0073508299673972)
# ('krome_idx_N2j', 1.0110702682889554)
# ('krome_idx_Nj', 1.011358175121609)
# ('krome_idx_NH2j', 1.012255338044527)
# ('krome_idx_NHj', 1.0145187099426862)
# ('krome_idx_HEj', 1.0149817494126736)
# ('krome_idx_H2Oj', 1.0188792337032986)
# ('krome_idx_H', 1.0320536580077704)
# ('krome_idx_NH', 1.0868350528643225)
# ('krome_idx_CN', 1.1241289417181723)
# < 1.375
# ('krome_idx_CH2', 1.125012781618741)
# ('krome_idx_C', 1.1318203497323591)
# ('krome_idx_Hj', 1.146819915649319)
# ('krome_idx_Cj', 1.1743388611138432)
# ('krome_idx_C2', 1.1939297609392798)
# ('krome_idx_CH2j', 1.1963501571989001)
# ('krome_idx_HNOj', 1.237016009400508)
# < 1.875
# ('krome_idx_C2Hj', 1.8166155473595589)
# < 2.125
# ('krome_idx_CHj', 1.9669650189986831)
# ('krome_idx_C2j', 2.0713234095609745)

# %%
test1,test2,Name,species_list = initial('case4','case4_1')
alpha(test1,test2,Name,species_list,8e-16,8e-16*1.1)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.6257634856012326)
# ('krome_idx_MG', -0.5770649554675089)
# < 0.125
# ('krome_idx_N2', -0.12302720419334763)
# ('krome_idx_H2', -0.09164028550299996)
# ('krome_idx_HCO', -0.03653413277545467)
# ('krome_idx_CO', -0.0017081944336465604)
# ('krome_idx_HE', -0.0)
# ('krome_idx_O', 0.00047843404875019786)
# ('krome_idx_O2', 0.000584580938817216)
# ('krome_idx_NH3', 0.06561907803629347)
# ('krome_idx_MGj', 0.09261607361278942)
# < 0.375
# ('krome_idx_E', 0.16715321032783487)
# ('krome_idx_H2O', 0.17901272678615715)
# ('krome_idx_N', 0.34265984482771594)
# < 0.625
# ('krome_idx_NO', 0.448156132612773)
# ('krome_idx_O2j', 0.6202745531766514)
# < 0.875
# ('krome_idx_N2Hj', 0.6517758816494414)
# ('krome_idx_HCOj', 0.7365922839377442)
# ('krome_idx_NH', 0.7531112089285897)
# ('krome_idx_HCN', 0.7735077777949968)
# ('krome_idx_CH', 0.7768321778025646)
# ('krome_idx_Hj', 0.7865667401789819)
# ('krome_idx_H3Oj', 0.8287994641259672)
# ('krome_idx_OH', 0.8490518068814649)
# ('krome_idx_CH2', 0.8709617601689051)
# < 1.125
# ('krome_idx_H3j', 0.9009385381036749)
# ('krome_idx_Cj', 0.9271122021503715)
# ('krome_idx_C', 0.9346232824715419)
# ('krome_idx_N2j', 0.9493568733761512)
# ('krome_idx_Nj', 0.9667524617875447)
# ('krome_idx_NH3j', 0.9673729040766673)
# ('krome_idx_Oj', 0.9787688076182861)
# ('krome_idx_HEj', 0.9804760703755141)
# ('krome_idx_H', 1.0000000000000187)
# ('krome_idx_NH2', 1.0364775530147117)
# ('krome_idx_H2j', 1.0636695992280383)
# ('krome_idx_CH3j', 1.0638535285220538)
# ('krome_idx_COj', 1.0699370964517885)
# ('krome_idx_H2Oj', 1.08709880238979)
# ('krome_idx_OHj', 1.0897029893636996)
# < 1.375
# ('krome_idx_CN', 1.1453582948980385)
# ('krome_idx_NHj', 1.1759861828934002)
# ('krome_idx_HNOj', 1.1861567518502334)
# ('krome_idx_NH2j', 1.2123822117828504)
# ('krome_idx_CH2j', 1.3152042668832413)
# < 1.625
# ('krome_idx_HCNHj', 1.440922534893112)
# < 1.875
# ('krome_idx_C2H2j', 1.6442639745402234)
# ('krome_idx_HCNj', 1.6885086955379474)
# ('krome_idx_CHj', 1.711852845875239)
# ('krome_idx_C2', 1.7829086167365498)
# ('krome_idx_C2j', 1.85133960014061)
# < 2.125
# ('krome_idx_C2Hj', 1.891676709883273)

# %%
test1,test2,Name,species_list = initial('case5','case5_1')
alpha(test1,test2,Name,species_list,8e-15,8e-15*1.1)
