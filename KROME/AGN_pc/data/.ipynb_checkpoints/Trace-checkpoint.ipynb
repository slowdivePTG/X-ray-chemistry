# %%
import numpy as np
import matplotlib.pyplot as plt
from species import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
# Get names of the species
with open('species') as data:
    line = data.readline()
    name = line.split(' ')

# %%
# Get names of the reactions
with open('../reactions_verbatim.dat') as data:
    reactions = data.readlines()

# %%
from numba import jit

# %%
class Trace():
    def __init__(self, file):
        with open(file) as f:
            lines = f.readlines()

        self.t = np.array([])
        self.species = np.array([])

        for line in lines:
            try:
                t = float(line)
                self.t = np.append(self.t, t)
                self.species = np.append(self.species, {})
                for na in name:
                    self.species[-1][na] = {}

            except:
                l = line.replace('   ', ' ')
                l = l.replace('  ', ' ')
                l = l.strip(' ')
                dat = l.split(' ')
                product = int(dat[0])
                self.species[-1][name[product - 1]][reactions[int(dat[1]) -
                                                              1]] = float(
                                                                  dat[2])
                self.species[-1][name[product - 1]] = dict(
                    sorted(self.species[-1][name[product - 1]].items(),
                           key=lambda item: item[1]))

    def spe_list(self, species):
        for item, i in enumerate(self.species):
            print(self.t[item])
            print('Destruction')
            li = list(i[species].keys())
            for num, j in enumerate(li[:5], 1):
                print(j, i[species][j])
            print('Formation')
            li.reverse()
            for num, j in enumerate(li[:5], 1):
                print(j, i[species][j])


tr = Trace('1Trace1')

# %%
tr.spe_list('H2O')
# Out:
# 1000.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -1.3584e-12
# HE+ + H2O -> H+ + OH + HE
#  -5.9321e-14
# HE+ + H2O -> OH+ + H + HE
#  -5.9321e-14
# HE+ + H2O -> H2O+ + HE
#  -5.9321e-14
# SI+ + H2O -> HSIO+ + H
#  -6.2324e-15
# Formation
# H3O+ + E -> H2O + H
#  1.5242e-12
# O- + H2 -> H2O + E
#  2.1732e-14
# H_DUSTH_DUSTO_DUST -> H2O
#  2.9105e-15
# OH- + H -> H2O + E
#  9.2815e-16
# H + OH -> H2O
#  6.3454e-17
# 2593.7
# Destruction
# H+ + H2O -> H2O+ + H
#  -9.5439e-13
# HE+ + H2O -> H+ + OH + HE
#  -4.649e-14
# HE+ + H2O -> OH+ + H + HE
#  -4.649e-14
# HE+ + H2O -> H2O+ + HE
#  -4.649e-14
# SI+ + H2O -> HSIO+ + H
#  -4.8934e-15
# Formation
# H3O+ + E -> H2O + H
#  1.073e-12
# O- + H2 -> H2O + E
#  1.9422e-14
# H_DUSTH_DUSTO_DUST -> H2O
#  7.4698e-15
# OH- + H -> H2O + E
#  8.305e-16
# H + OH -> H2O
#  7.635e-17
# 6727.5
# Destruction
# H+ + H2O -> H2O+ + H
#  -6.3545e-13
# HE+ + H2O -> H+ + OH + HE
#  -3.3324e-14
# HE+ + H2O -> OH+ + H + HE
#  -3.3324e-14
# HE+ + H2O -> H2O+ + HE
#  -3.3324e-14
# SI+ + H2O -> HSIO+ + H
#  -3.4597e-15
# Formation
# H3O+ + E -> H2O + H
#  7.0258e-13
# H_DUSTH_DUSTO_DUST -> H2O
#  1.8847e-14
# O- + H2 -> H2O + E
#  1.7816e-14
# OH- + H -> H2O + E
#  7.6246e-16
# H + OH -> H2O
#  8.2817e-17
# 17449.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -4.3292e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.3796e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.3796e-14
# HE+ + H2O -> H2O+ + HE
#  -2.3796e-14
# SI+ + H2O -> HSIO+ + H
#  -2.4599e-15
# Formation
# H3O+ + E -> H2O + H
#  4.4513e-13
# H_DUSTH_DUSTO_DUST -> H2O
#  4.5559e-14
# O- + H2 -> H2O + E
#  1.6024e-14
# OH- + H -> H2O + E
#  6.861e-16
# H + OH -> H2O
#  8.55e-17
# 45259.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.4458e-13
# HE+ + H2O -> H+ + OH + HE
#  -1.9516e-14
# HE+ + H2O -> OH+ + H + HE
#  -1.9516e-14
# HE+ + H2O -> H2O+ + HE
#  -1.9516e-14
# SI+ + H2O -> HSIO+ + H
#  -1.9966e-15
# Formation
# H3O+ + E -> H2O + H
#  2.9157e-13
# H_DUSTH_DUSTO_DUST -> H2O
#  9.9246e-14
# O- + H2 -> H2O + E
#  1.4113e-14
# OH- + H -> H2O + E
#  6.0448e-16
# H + OH -> H2O
#  8.6842e-17
# 117390.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.4276e-13
# HE+ + H2O -> H+ + OH + HE
#  -1.9719e-14
# HE+ + H2O -> OH+ + H + HE
#  -1.9719e-14
# HE+ + H2O -> H2O+ + HE
#  -1.9719e-14
# SI+ + H2O -> HSIO+ + H
#  -2.007e-15
# Formation
# H3O+ + E -> H2O + H
#  2.1872e-13
# H_DUSTH_DUSTO_DUST -> H2O
#  1.7272e-13
# O- + H2 -> H2O + E
#  1.2322e-14
# OH- + H -> H2O + E
#  5.2783e-16
# H + OH -> H2O
#  9.0714e-17
# 304480.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6019e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0832e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0832e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0832e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1198e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1397e-13
# H3O+ + E -> H2O + H
#  1.992e-13
# O- + H2 -> H2O + E
#  1.1516e-14
# OH- + H -> H2O + E
#  4.9332e-16
# H + OH -> H2O
#  9.3917e-17
# 789750.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6221e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0958e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0958e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0958e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1325e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1764e-13
# H3O+ + E -> H2O + H
#  1.9801e-13
# O- + H2 -> H2O + E
#  1.1453e-14
# OH- + H -> H2O + E
#  4.9064e-16
# H + OH -> H2O
#  9.4216e-17
# 2048400.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6221e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0958e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0958e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0958e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1325e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1764e-13
# H3O+ + E -> H2O + H
#  1.9801e-13
# O- + H2 -> H2O + E
#  1.1453e-14
# OH- + H -> H2O + E
#  4.9063e-16
# H + OH -> H2O
#  9.4216e-17
# 5313000.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6221e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0958e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0958e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0958e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1325e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1764e-13
# H3O+ + E -> H2O + H
#  1.9801e-13
# O- + H2 -> H2O + E
#  1.1453e-14
# OH- + H -> H2O + E
#  4.9063e-16
# H + OH -> H2O
#  9.4216e-17
# 13781000.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6221e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0958e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0958e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0958e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1325e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1764e-13
# H3O+ + E -> H2O + H
#  1.9801e-13
# O- + H2 -> H2O + E
#  1.1453e-14
# OH- + H -> H2O + E
#  4.9063e-16
# H + OH -> H2O
#  9.4216e-17
# 35743000.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6221e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0958e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0958e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0958e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1325e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1764e-13
# H3O+ + E -> H2O + H
#  1.9801e-13
# O- + H2 -> H2O + E
#  1.1453e-14
# OH- + H -> H2O + E
#  4.9063e-16
# H + OH -> H2O
#  9.4216e-17
# 92709000.0
# Destruction
# H+ + H2O -> H2O+ + H
#  -3.6221e-13
# HE+ + H2O -> H+ + OH + HE
#  -2.0958e-14
# HE+ + H2O -> OH+ + H + HE
#  -2.0958e-14
# HE+ + H2O -> H2O+ + HE
#  -2.0958e-14
# SI+ + H2O -> HSIO+ + H
#  -2.1325e-15
# Formation
# H_DUSTH_DUSTO_DUST -> H2O
#  2.1764e-13
# H3O+ + E -> H2O + H
#  1.9801e-13
# O- + H2 -> H2O + E
#  1.1453e-14
# OH- + H -> H2O + E
#  4.9063e-16
# H + OH -> H2O
#  9.4216e-17
