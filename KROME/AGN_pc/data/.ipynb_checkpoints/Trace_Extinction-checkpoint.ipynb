# %%
# %load_ext autoreload
# %autoreload 2
from Trace import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
tr104 = Trace('1Trace04')
tr304 = Trace('3Trace04')

# %%
tr1inf = Trace('1Trace_inf')
tr2inf = Trace('2Trace_inf')
tr3inf = Trace('3Trace_inf')

# %%
tr104.plot('H_DUSTH_DUSTO_DUST', num=3, two_periods=True)
tr304.plot('H_DUSTH_DUSTO_DUST', num=3, two_periods=True)

# %%
tr1inf.plot('H_DUSTH_DUSTO_DUST', num=3, two_periods=True)
tr3inf.plot('H_DUSTH_DUSTO_DUST', num=3, two_periods=True)

# %%
tr104.plot('H2O', num=3)
tr304.plot('H2O', num=3)

# %%
tr1inf.plot('H2O', num=3)
tr3inf.plot('H2O', num=3)

# %%
tr104.plot('CH3OH', num=3)
tr304.plot('CH3OH', num=3)

# %%
tr1inf.plot('CH3OH', num=3)
tr3inf.plot('CH3OH', num=3)

# %%
tr104.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3)
tr304.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3)

# %%
tr1inf.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3, two_periods=True)
tr3inf.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3, two_periods=True)

# %%
tr104.plot('H2CO', num=3)
tr304.plot('H2CO', num=3)

# %%
tr1inf.plot('H2CO', num=3)
tr3inf.plot('H2CO', num=3)

# %%
tr104.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3)
tr304.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3)

# %%
tr1inf.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3, two_periods=True)
tr3inf.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3, two_periods=True)
