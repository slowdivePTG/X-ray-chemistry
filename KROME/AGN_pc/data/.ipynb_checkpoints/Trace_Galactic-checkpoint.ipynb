# %%
# %load_ext autoreload
# %autoreload 2
from Trace import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
tr21 = Trace('2Trace1')
tr201 = Trace('2Trace01')
tr22 = Trace('2Trace2')
tr202 = Trace('2Trace02')
tr24 = Trace('2Trace4')
tr204 = Trace('2Trace04')
tr28 = Trace('2Trace8')
tr208 = Trace('2Trace08')

# %%
tr2inf = Trace('2Trace_inf')

# %%
tr201.plot('H_DUSTH_DUSTO_DUST', num=2)
tr202.plot('H_DUSTH_DUSTO_DUST', num=2)
tr204.plot('H_DUSTH_DUSTO_DUST', num=2)
tr208.plot('H_DUSTH_DUSTO_DUST', num=2)
tr2inf.plot('H_DUSTH_DUSTO_DUST', num=2)

# %%
tr201.plot('H2O', num=2, two_periods=True)
tr202.plot('H2O', num=2, two_periods=True)
tr204.plot('H2O', num=2, two_periods=True)
tr208.plot('H2O', num=2, two_periods=True)
tr2inf.plot('H2O', num=2, two_periods=True)

# %%
tr201.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=2)
tr202.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=2)
tr204.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=2)
tr208.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=2)
tr2inf.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=2)

# %%
tr201.plot('CH3OH', num=2)
tr202.plot('CH3OH', num=2)
tr204.plot('CH3OH', num=2)
tr208.plot('CH3OH', num=2)
tr2inf.plot('CH3OH', num=2)

# %%
tr201.plot('C_DUSTO_DUST', num=2)
tr202.plot('C_DUSTO_DUST', num=2)
tr204.plot('C_DUSTO_DUST', num=2)
tr208.plot('C_DUSTO_DUST', num=2)
tr2inf.plot('C_DUSTO_DUST', num=2)

# %%
tr201.plot('H2CO', num=2)
tr202.plot('H2CO', num=2)
tr204.plot('H2CO', num=2)
tr208.plot('H2CO', num=2)
tr2inf.plot('H2CO', num=2)

# %%
tr201.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=2)
tr202.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=2)
tr204.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=2)
tr208.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=2)
tr2inf.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=2)
