# %%
# %load_ext autoreload
# %autoreload 2
from Trace import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
tr24 = Trace('2Trace4')
tr204 = Trace('2Trace04')

# %%
tr2inf = Trace('2Trace_inf')

# %%
tr24_7 = Trace('2Trace41e+07')
tr204_7 = Trace('2Trace041e+07')

# %%
tr2inf_7 = Trace('2Trace_inf1e+07')

# %%
tr24_7.plot('H2O', num=3)
tr204_7.plot('H2O', num=3)
tr2inf_7.plot('H2O', num=3)

# %%
tr24_7.plot('H_DUSTH_DUSTO_DUST', num=3)
tr204_7.plot('H_DUSTH_DUSTO_DUST', num=3)
tr2inf_7.plot('H_DUSTH_DUSTO_DUST', num=3)

# %%
tr24_7.plot('CH3OH', num=2)
tr204_7.plot('CH3OH', num=2)
tr2inf_7.plot('CH3OH', num=3)

# %%
tr24_7.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3)
tr204_7.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3)
tr2inf_7.plot('C_DUSTH_DUSTH_DUSTH_DUSTO_DUSTH_DUST', num=3)

# %%
tr24_7.plot('H2CO', num=3)
tr204_7.plot('H2CO', num=3)
tr2inf_7.plot('H2CO', num=3)

# %%
tr24_7.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3)
tr204_7.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3)
tr2inf_7.plot('H_DUSTH_DUSTC_DUSTO_DUST', num=3)
