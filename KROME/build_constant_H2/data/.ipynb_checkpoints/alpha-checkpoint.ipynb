# %%
import numpy as np
from species import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
def initial(txt1,txt2):
    test1=np.loadtxt(txt1)[-1]
    test2=np.loadtxt(txt2)[-1]
    data1 = open('Name')
    Name = []
    while 1:
        line = data1.readline()
        if not line:
            break
        line=line.strip('\n')
        temp='krome_idx_'+line.upper()
        if (temp[-1]=='J'):
            temp=temp[0:-1]+'j'
        Name.append(temp)
    species_list=[]
    for name in Name:
        species_list.append(name)
    return(test1,test2,Name,species_list)

# %%
def log_dev(a,b,zeta1,zeta2):
    y=np.log(a)-np.log(b)
    x=np.log(zeta1)-np.log(zeta2)
    return(y/x)

# %%
def alpha(test1,test2,Name,species_list,zeta1,zeta2):
    list_elementd = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        list_elementd.update(temp_dic)

    dict_out = sorted(list_elementd.items(), key = lambda item:item[1])
    gap = -0.375
    print('<',gap)
    for i in dict_out:
        if i[1] > gap:
            while (gap) < i[1]:
                gap += 0.25
            print ('<',gap)
        print(i)

# %%
test1,test2,Name,species_list = initial('case1','case1_1')
#alpha(test1,test2,Name,species_list,6.8e-18,7.8e-18)
test1[krome_idx_HCNj]
# Out:
# 9.2501e-19

# %%
test1,test2,Name,species_list = initial('case2','case2_1')
#alpha(test1,test2,Name,species_list,6.8e-16,7.8e-16)
test1[krome_idx_HCNj]
# Out:
# 3.4026e-16

# %%
test1,test2,Name,species_list = initial('case3','case3_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# < 0.125
# ('krome_idx_CO2', -0.027718643695423303)
# ('krome_idx_NH3', -0.006403906903457678)
# ('krome_idx_MG', -0.0041123263015449465)
# ('krome_idx_O2', -0.0025226751012726446)
# ('krome_idx_N2', -0.000519419949038117)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_CO', 0.0010341487949929375)
# ('krome_idx_O', 0.005935363532996495)
# ('krome_idx_H2O', 0.007204797360964242)
# ('krome_idx_N', 0.01574692207329974)
# ('krome_idx_E', 0.018799726881122122)
# ('krome_idx_MGj', 0.022873050225029827)
# ('krome_idx_HCO', 0.02565870681337735)
# ('krome_idx_H', 0.030866216315893865)
# ('krome_idx_HCOj', 0.03913128765408863)
# ('krome_idx_O2j', 0.041448169337247126)
# ('krome_idx_H3Oj', 0.042640317446587306)
# ('krome_idx_HCN', 0.04479184643116662)
# ('krome_idx_N2Hj', 0.049332935329019965)
# ('krome_idx_CH3j', 0.05023970140861706)
# ('krome_idx_NO', 0.050678076891837225)
# ('krome_idx_NH3j', 0.05071844010288774)
# ('krome_idx_NH2', 0.05165415327724602)
# ('krome_idx_OH', 0.05290045780055487)
# ('krome_idx_H3j', 0.05685572000207269)
# ('krome_idx_CH2', 0.05696172606683057)
# ('krome_idx_CH', 0.057395283218141774)
# ('krome_idx_Oj', 0.059644962825225356)
# ('krome_idx_N2j', 0.06004747079329758)
# ('krome_idx_NHj', 0.060053318336031655)
# ('krome_idx_Nj', 0.060130879097394174)
# ('krome_idx_HEj', 0.060334577235693986)
# ('krome_idx_NH2j', 0.060546206040946134)
# ('krome_idx_COj', 0.06061077165909845)
# ('krome_idx_H2j', 0.060666563982653396)
# ('krome_idx_C', 0.06072316412203839)
# ('krome_idx_OHj', 0.06182149620738418)
# ('krome_idx_NH', 0.061885321628482697)
# ('krome_idx_H2Oj', 0.062242528895539974)
# ('krome_idx_Hj', 0.06252750377878889)
# ('krome_idx_C2H2j', 0.06296637721124683)
# ('krome_idx_Cj', 0.06351808875398059)
# ('krome_idx_CH2j', 0.066266483373948)
# ('krome_idx_C2', 0.07361849846867718)
# ('krome_idx_CN', 0.07617724335169317)
# ('krome_idx_HCNHj', 0.07896558695372678)
# ('krome_idx_HNOj', 0.09325839006411983)
# ('krome_idx_HCNj', 0.1111919991452968)
# ('krome_idx_CHj', 0.11388938918901316)
# ('krome_idx_C2Hj', 0.11489748691586396)
# ('krome_idx_C2j', 0.11942990507003709)

# %%
test1,test2,Name,species_list = initial('case4','case4_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# < 0.125
# ('krome_idx_CO2', -0.04081700761965441)
# ('krome_idx_MG', -0.022828382673957183)
# ('krome_idx_NH3', -0.006472754993143585)
# ('krome_idx_N2', -0.0032657769598889845)
# ('krome_idx_O2', -0.0028383802678882404)
# ('krome_idx_CO', -0.00034446945828139577)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_HCO', 0.0004399290114734193)
# ('krome_idx_O', 0.005441116431223578)
# ('krome_idx_H2O', 0.006718699846429375)
# ('krome_idx_MGj', 0.013960798949069236)
# ('krome_idx_E', 0.014747402412269454)
# ('krome_idx_N', 0.023518849699949416)
# ('krome_idx_H', 0.031018243151430664)
# ('krome_idx_NO', 0.03151773964092008)
# ('krome_idx_HCOj', 0.03916187563901286)
# ('krome_idx_O2j', 0.040071885623516254)
# ('krome_idx_N2Hj', 0.04071956178294184)
# ('krome_idx_H3Oj', 0.0473457812811954)
# ('krome_idx_NH', 0.04879666410470841)
# ('krome_idx_CH', 0.04942166128040567)
# ('krome_idx_OH', 0.05101194701113354)
# ('krome_idx_HCN', 0.05219231203465723)
# ('krome_idx_H3j', 0.05426855262329604)
# ('krome_idx_N2j', 0.0575732350360522)
# ('krome_idx_Hj', 0.05785558478703762)
# ('krome_idx_Oj', 0.059206312249522546)
# ('krome_idx_NH3j', 0.05924975462130553)
# ('krome_idx_C', 0.05927007142811989)
# ('krome_idx_COj', 0.05937904774323012)
# ('krome_idx_H2j', 0.06049301098289525)
# ('krome_idx_HEj', 0.06058363921125031)
# ('krome_idx_OHj', 0.06065613321390401)
# ('krome_idx_Nj', 0.06101146299564982)
# ('krome_idx_Cj', 0.0610237361890013)
# ('krome_idx_NH2', 0.061922961274752795)
# ('krome_idx_H2Oj', 0.06259118904779612)
# ('krome_idx_NHj', 0.0644553742298696)
# ('krome_idx_CH2', 0.06980295082652505)
# ('krome_idx_NH2j', 0.07077278772081291)
# ('krome_idx_HNOj', 0.07246559574357411)
# ('krome_idx_CH3j', 0.07588023913691279)
# ('krome_idx_CN', 0.08396964515220316)
# ('krome_idx_CH2j', 0.09014069087434456)
# ('krome_idx_HCNHj', 0.09291220831606424)
# ('krome_idx_C2H2j', 0.09708944790885166)
# ('krome_idx_C2', 0.10539617968367888)
# ('krome_idx_CHj', 0.10888079805847137)
# ('krome_idx_C2j', 0.11080811108007073)
# ('krome_idx_C2Hj', 0.11082159886615589)
# ('krome_idx_HCNj', 0.1123921653160017)

# %%
test1,test2,Name,species_list = initial('case5','case5_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_MG', -0.4483470417900231)
# ('krome_idx_N2', -0.4244135569814361)
# < 0.125
# ('krome_idx_NH3', -0.08794675138500913)
# ('krome_idx_NO', -0.047863274895087654)
# ('krome_idx_H2O', -0.005869949371704675)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_MGj', 0.001543786175530141)
# ('krome_idx_CN', 0.07245262588002863)
# ('krome_idx_N2Hj', 0.08006475572439095)
# ('krome_idx_E', 0.09978092938511234)
# < 0.375
# ('krome_idx_NH2', 0.12590611402251617)
# ('krome_idx_N2j', 0.12606000440825046)
# ('krome_idx_HCN', 0.19078227509232104)
# ('krome_idx_CO', 0.20571599944616242)
# ('krome_idx_OH', 0.20999633886764482)
# ('krome_idx_H', 0.2136531968309666)
# ('krome_idx_C2', 0.34456989542728744)
# ('krome_idx_CO2', 0.35159894596739155)
# ('krome_idx_HCNHj', 0.35763796068106346)
# < 0.625
# ('krome_idx_O2', 0.41038245830617326)
# ('krome_idx_NH3j', 0.4142936006927615)
# ('krome_idx_O', 0.42407113196668544)
# ('krome_idx_HNOj', 0.4340589481234703)
# ('krome_idx_H3Oj', 0.45938391874377554)
# ('krome_idx_NH2j', 0.46496167627949664)
# ('krome_idx_NHj', 0.4851141463699575)
# ('krome_idx_HCNj', 0.4918134383751708)
# ('krome_idx_NH', 0.5110267286154866)
# ('krome_idx_N', 0.5220420585912954)
# ('krome_idx_H3j', 0.5400604439863949)
# ('krome_idx_Hj', 0.5441711434414569)
# ('krome_idx_HEj', 0.5504696806594515)
# ('krome_idx_H2j', 0.5748690395567702)
# ('krome_idx_OHj', 0.5983315146507906)
# ('krome_idx_HCO', 0.6122678389220593)
# ('krome_idx_H2Oj', 0.6157888104147275)
# < 0.875
# ('krome_idx_Nj', 0.6338136622594818)
# ('krome_idx_CH3j', 0.6396592455658935)
# ('krome_idx_HCOj', 0.7080518880084739)
# ('krome_idx_Cj', 0.7375154159997216)
# ('krome_idx_CH2', 0.7394705763934367)
# ('krome_idx_Oj', 0.7412836879405471)
# ('krome_idx_C', 0.744112939351285)
# ('krome_idx_CH2j', 0.7452292494129725)
# ('krome_idx_CHj', 0.7529779602181887)
# ('krome_idx_CH', 0.7540101508527781)
# ('krome_idx_C2H2j', 0.803726525718141)
# ('krome_idx_O2j', 0.8718250074745024)
# < 1.125
# ('krome_idx_C2j', 0.8807349132214131)
# ('krome_idx_C2Hj', 0.8852092837362352)
# ('krome_idx_COj', 0.9002649035864365)

# %%
import matplotlib.pyplot as plt 
def alpha_range(krolik_table,txt1,txt2,zeta1,zeta2):
    test1,test2,Name,species_list = initial(txt1,txt2)
    user_alpha = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        user_alpha.update(temp_dic)
    krolik_range = {}
    data1 = open(krolik_table)
    title = ''
    while 1:
        line = data1.readline()
        if not line:
            break
        if line[0]=='#':
            title = line[1:-1]
            continue
        line = line.strip('\n').upper()
        line = line.replace('+','j')
        alpha = float(line[0:line.find(' ')])
        temp = line[line.find(' '):-1]
        temp = temp.replace(' ','')
        temp_list = temp.split(',')
        for i in temp_list:
            temp_dic = {i:alpha}
            krolik_range.update(temp_dic)
    me = [] # Store my calculation
    krolik = [] #Store the range of alpha
    names = []
    for key in krolik_range:
        temp = 'krome_idx_'+key
        me.append(user_alpha[temp]) #My Calculation
        krolik.append(krolik_range[key]) #Krolik's Results
        names.append(key.replace('j','+'))
    me, krolik = np.array(me), np.array(krolik)
    i = np.arange(len(krolik_range))
    plt.figure(figsize=(30,15))
    #plt.title(title,fontsize=30)
    plt.fill_between(i, krolik, krolik+0.25, alpha=0.5, edgecolor='#89916B', facecolor='#B5CAA0')
    for j in range(len(me)):
        col = '#CC543A' #Color of the dot
        if ((krolik[j]-0.25<me[j]) and (me[j]<krolik[j]+0.50)):
            col = '#86A697'
        else:
            plt.text(i[j]-0.15*(len(names[j])-1),me[j]-0.125,names[j],fontsize=15)
        plt.scatter(i[j],me[j],color=col)
    plt.xticks(i, names,fontsize=20, rotation=60)
    plt.yticks(fontsize=30)
    plt.ylabel(r'$\alpha$',fontsize=30)
    plt.savefig(krolik_table+'.png')
    plt.show()

# %%
# Cosmic Ray 6.8e-18
alpha_range('Table1','case1','case1_1',6.8,7.8)

# %%
# Cosmic Ray 6.8e-16
alpha_range('Table2','case2','case2_1',6.8,7.8)

# %%
# X-ray Jx21=0.08
alpha_range('Table3','case3','case3_1',1,1.2)

# %%
# X-ray Jx21=0.08
alpha_range('Table3','case3','case3_1',9,9.1)

# %%
# X-ray Jx21=8
alpha_range('Table4','case4','case4_1',9, 9.1)

# %%
# X-ray Jx21=8
alpha_range('Table4','case4','case4_1',9,9.1)

# %%
# X-ray Jx21=80
alpha_range('Table5','case4','case4_1',9,9.1)
