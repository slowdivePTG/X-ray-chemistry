# %%
import numpy as np
from species import *
# Out:
# All variables set as e.g. krome_idx_H2
# plot 'your_output' u 1:krome_idx_H2
#  the offset is nkrome= 0

# %%
def initial(txt1,txt2):
    test1=np.loadtxt(txt1)[-1]
    test2=np.loadtxt(txt2)[-1]
    data1 = open('Name')
    Name = []
    while 1:
        line = data1.readline()
        if not line:
            break
        line=line.strip('\n')
        temp='krome_idx_'+line.upper()
        if (temp[-1]=='J'):
            temp=temp[0:-1]+'j'
        Name.append(temp)
    species_list=[]
    for name in Name:
        species_list.append(name)
    return(test1,test2,Name,species_list)

# %%
def log_dev(a,b,zeta1,zeta2):
    y=np.log(a)-np.log(b)
    x=np.log(zeta1)-np.log(zeta2)
    return(y/x)

# %%
def alpha(test1,test2,Name,species_list,zeta1,zeta2):
    list_elementd = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        list_elementd.update(temp_dic)

    dict_out = sorted(list_elementd.items(), key = lambda item:item[1])
    gap = -0.375
    print('<',gap)
    for i in dict_out:
        if i[1] > gap:
            while (gap) < i[1]:
                gap += 0.25
            print ('<',gap)
        print(i)

# %%
test1,test2,Name,species_list = initial('case1','case1_1')
alpha(test1,test2,Name,species_list,6.8e-18,7.8e-18)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.5936355307762219)
# < -0.125
# ('krome_idx_NH3', -0.1434582942284767)
# < 0.125
# ('krome_idx_MG', -0.07880564455453908)
# ('krome_idx_O2', -0.04474628865857417)
# ('krome_idx_N2', -0.007623665578389718)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_CO', 0.003391290305468696)
# ('krome_idx_O', 0.08605259531956033)
# ('krome_idx_HCN', 0.0932977109224672)
# < 0.375
# ('krome_idx_H2O', 0.14262874361760683)
# ('krome_idx_N', 0.33509761978401387)
# < 0.625
# ('krome_idx_MGj', 0.4486128748249291)
# ('krome_idx_E', 0.45149968976280247)
# ('krome_idx_HCO', 0.6243102882178478)
# < 0.875
# ('krome_idx_HCNHj', 0.7832255100633051)
# ('krome_idx_HCOj', 0.8146813265495015)
# ('krome_idx_O2j', 0.86074245914222)
# < 1.125
# ('krome_idx_H3Oj', 0.8834190361850973)
# ('krome_idx_CH3j', 1.043329571444813)
# ('krome_idx_NH3j', 1.0854466450754396)
# ('krome_idx_N2Hj', 1.0885834264037597)
# < 1.375
# ('krome_idx_C2H2j', 1.141474113191815)
# ('krome_idx_NO', 1.1658200743627993)
# ('krome_idx_NH2', 1.1707005392420844)
# ('krome_idx_OH', 1.2079462860265313)
# ('krome_idx_CH', 1.2420474173439835)
# ('krome_idx_H3j', 1.2567948208323694)
# ('krome_idx_CH2', 1.3035702307067472)
# ('krome_idx_COj', 1.3157749352686996)
# ('krome_idx_N2j', 1.323915403055475)
# ('krome_idx_H2j', 1.327154131163563)
# ('krome_idx_HEj', 1.3311777913729883)
# ('krome_idx_Nj', 1.3360126202141256)
# ('krome_idx_NH2j', 1.336437764068408)
# ('krome_idx_NHj', 1.3369478678404056)
# ('krome_idx_Oj', 1.3400014215011986)
# ('krome_idx_OHj', 1.3431553595112438)
# ('krome_idx_C', 1.3476473143873786)
# ('krome_idx_H', 1.351412712118974)
# ('krome_idx_H2Oj', 1.3525229324759147)
# ('krome_idx_Hj', 1.3539532252778963)
# ('krome_idx_Cj', 1.370742508302731)
# < 1.625
# ('krome_idx_CH2j', 1.4255852398089301)
# ('krome_idx_HCNj', 1.442104961118689)
# ('krome_idx_NH', 1.4458613577666337)
# ('krome_idx_CN', 1.5323700790610741)
# ('krome_idx_C2', 1.5371599139675844)
# < 2.125
# ('krome_idx_HNOj', 2.045693305630176)
# < 2.375
# ('krome_idx_CHj', 2.2762312447576436)
# < 2.625
# ('krome_idx_C2Hj', 2.44009492325386)
# ('krome_idx_C2j', 2.56578799884489)

# %%
test1,test2,Name,species_list = initial('case2','case2_1')
alpha(test1,test2,Name,species_list,6.8e-16,7.8e-16)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.9629410410705308)
# < -0.125
# ('krome_idx_MG', -0.29263113042915695)
# ('krome_idx_HCO', -0.172870414937548)
# ('krome_idx_NH3', -0.14577193664667837)
# < 0.125
# ('krome_idx_O2', -0.08557528855128141)
# ('krome_idx_N2', -0.03440982815302776)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_CO', -0.0)
# ('krome_idx_H2O', 0.05516215961161254)
# ('krome_idx_O', 0.0917961912867572)
# < 0.375
# ('krome_idx_MGj', 0.2706726218808854)
# ('krome_idx_E', 0.2789672640482258)
# ('krome_idx_N', 0.37341702517145914)
# < 0.625
# ('krome_idx_HCN', 0.5018389810559136)
# ('krome_idx_NO', 0.5810015408172876)
# ('krome_idx_HCOj', 0.6206909114878242)
# < 0.875
# ('krome_idx_O2j', 0.6496464118724992)
# ('krome_idx_N2Hj', 0.6811748257688808)
# ('krome_idx_H3Oj', 0.7088132037578135)
# ('krome_idx_CH', 0.8050005561285108)
# ('krome_idx_CH2', 0.8062615076036378)
# ('krome_idx_NH3j', 0.8345633070542036)
# ('krome_idx_OH', 0.8482417163114551)
# ('krome_idx_NH', 0.8602165627505679)
# < 1.125
# ('krome_idx_H3j', 0.895844767750724)
# ('krome_idx_NH2', 0.9364422475249494)
# ('krome_idx_Oj', 0.9678118781333783)
# ('krome_idx_N2j', 0.9730877827661777)
# ('krome_idx_OHj', 0.9871929280823144)
# ('krome_idx_COj', 0.9892112416436832)
# ('krome_idx_H2j', 0.9999133094323582)
# ('krome_idx_H2Oj', 1.0011839738435795)
# ('krome_idx_Nj', 1.0043032650224024)
# ('krome_idx_HEj', 1.0072565286637019)
# ('krome_idx_NHj', 1.0173123017332293)
# ('krome_idx_Hj', 1.0185348270080408)
# ('krome_idx_H', 1.0192919049394955)
# ('krome_idx_C', 1.043379482034069)
# ('krome_idx_NH2j', 1.060048823739127)
# ('krome_idx_Cj', 1.065501694094205)
# ('krome_idx_CH3j', 1.0725424392669052)
# < 1.375
# ('krome_idx_HCNHj', 1.1409310615840755)
# ('krome_idx_HNOj', 1.229351805726735)
# ('krome_idx_CN', 1.2968070516215697)
# ('krome_idx_CH2j', 1.3365966897947517)
# < 1.625
# ('krome_idx_C2H2j', 1.6048654485316232)
# < 1.875
# ('krome_idx_HCNj', 1.6910474834760139)
# ('krome_idx_C2', 1.7833514976385463)
# ('krome_idx_CHj', 1.8433871824444061)
# ('krome_idx_C2j', 1.8717483963166583)
# ('krome_idx_C2Hj', 1.8720019412253017)

# %%
test1,test2,Name,species_list = initial('case3','case3_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.46757698287578464)
# < 0.125
# ('krome_idx_NH3', -0.10763974807444524)
# ('krome_idx_MG', -0.059478945083157535)
# ('krome_idx_O2', -0.03340424565844785)
# ('krome_idx_N2', -0.005737527452515605)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2', -0.0)
# ('krome_idx_CO', 0.002482003940572595)
# ('krome_idx_O', 0.06387616637728676)
# ('krome_idx_HCN', 0.0691711635077796)
# ('krome_idx_H2O', 0.10639246544709922)
# < 0.375
# ('krome_idx_N', 0.2502655135495528)
# ('krome_idx_MGj', 0.338801487507738)
# ('krome_idx_E', 0.3389579464955522)
# < 0.625
# ('krome_idx_HCO', 0.44956452354366433)
# ('krome_idx_H', 0.508377265876084)
# ('krome_idx_HCNHj', 0.5893649081245287)
# ('krome_idx_HCOj', 0.6138870789044943)
# < 0.875
# ('krome_idx_O2j', 0.648277651355403)
# ('krome_idx_H3Oj', 0.6650052189851645)
# ('krome_idx_CH3j', 0.7850958507989886)
# ('krome_idx_NH3j', 0.8172293337826375)
# ('krome_idx_N2Hj', 0.8198075545960665)
# ('krome_idx_C2H2j', 0.8552980341416037)
# < 1.125
# ('krome_idx_NO', 0.879031374351097)
# ('krome_idx_NH2', 0.8822640621727624)
# ('krome_idx_OH', 0.9100971217417461)
# ('krome_idx_CH', 0.9335593845819746)
# ('krome_idx_H3j', 0.9460602322166318)
# ('krome_idx_CH2', 0.9613694045308596)
# ('krome_idx_COj', 0.9902519265370355)
# ('krome_idx_N2j', 0.9963737269469117)
# ('krome_idx_H2j', 0.9985827517938141)
# ('krome_idx_HEj', 1.0017438923107875)
# ('krome_idx_Nj', 1.0053331163590464)
# ('krome_idx_NH2j', 1.0056024993864567)
# ('krome_idx_NHj', 1.0059123886782566)
# ('krome_idx_Oj', 1.0085882642793753)
# ('krome_idx_OHj', 1.010145087631161)
# ('krome_idx_C', 1.0146008736504044)
# ('krome_idx_H2Oj', 1.0171272342159074)
# ('krome_idx_Hj', 1.018568543894724)
# ('krome_idx_Cj', 1.0312447909251201)
# ('krome_idx_CH2j', 1.0719814429624663)
# ('krome_idx_HCNj', 1.083688295626907)
# ('krome_idx_NH', 1.08895080362542)
# < 1.375
# ('krome_idx_CN', 1.1502657597367412)
# ('krome_idx_C2', 1.1533184924359454)
# < 1.625
# ('krome_idx_HNOj', 1.5405457213223401)
# < 1.875
# ('krome_idx_CHj', 1.7120512034513744)
# ('krome_idx_C2Hj', 1.8344522379965968)
# < 2.125
# ('krome_idx_C2j', 1.9289074194386617)

# %%
test1,test2,Name,species_list = initial('case4','case4_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_CO2', -0.9727146476516415)
# ('krome_idx_MG', -0.38508589666634985)
# < -0.125
# ('krome_idx_HCO', -0.33910470826835565)
# < 0.125
# ('krome_idx_O2', -0.08223123188201313)
# ('krome_idx_N2', -0.050443587021356324)
# ('krome_idx_NH3', -0.030599808972471422)
# ('krome_idx_CO', -0.001236556481426168)
# ('krome_idx_H2', -0.00010970178404691013)
# ('krome_idx_HE', -0.0)
# ('krome_idx_H2O', 0.0739060793903191)
# ('krome_idx_O', 0.07711073835435665)
# < 0.375
# ('krome_idx_MGj', 0.23476989468346274)
# ('krome_idx_E', 0.24719120544061057)
# < 0.625
# ('krome_idx_N', 0.4092499239093828)
# ('krome_idx_NO', 0.4930163477185374)
# < 0.875
# ('krome_idx_HCOj', 0.6421845865673577)
# ('krome_idx_O2j', 0.6433159242809078)
# ('krome_idx_N2Hj', 0.6657972402393123)
# ('krome_idx_HCN', 0.6840513309361177)
# ('krome_idx_H3Oj', 0.7501224041056902)
# ('krome_idx_CH', 0.7561432728540806)
# ('krome_idx_CH2', 0.78542270869757)
# ('krome_idx_NH', 0.823583741525057)
# ('krome_idx_OH', 0.8540558822716379)
# < 1.125
# ('krome_idx_H3j', 0.887152220995957)
# ('krome_idx_NH3j', 0.9231146065531334)
# ('krome_idx_N2j', 0.9448556445718773)
# ('krome_idx_Hj', 0.9699571565268575)
# ('krome_idx_COj', 0.9754796125378822)
# ('krome_idx_OHj', 0.9873646395999367)
# ('krome_idx_H2j', 0.9900639751620516)
# ('krome_idx_HEj', 0.9934552125716031)
# ('krome_idx_Oj', 0.9996245436238068)
# ('krome_idx_H2Oj', 1.007304936358635)
# ('krome_idx_H', 1.0118235074450666)
# ('krome_idx_NH2', 1.0213867424838587)
# ('krome_idx_Nj', 1.0333642679561381)
# ('krome_idx_Cj', 1.0336478575405499)
# ('krome_idx_C', 1.052682714266328)
# ('krome_idx_NHj', 1.0723130592378594)
# < 1.375
# ('krome_idx_NH2j', 1.1325164014732887)
# ('krome_idx_HNOj', 1.1559174315917542)
# ('krome_idx_CH3j', 1.2526294675711631)
# ('krome_idx_CN', 1.3435485859893772)
# ('krome_idx_HCNHj', 1.3519015601788826)
# < 1.625
# ('krome_idx_CH2j', 1.4892401590603435)
# ('krome_idx_C2H2j', 1.5683862272578935)
# < 1.875
# ('krome_idx_C2', 1.7275745831620308)
# ('krome_idx_HCNj', 1.7595446326113386)
# ('krome_idx_C2j', 1.794179258205351)
# ('krome_idx_C2Hj', 1.79804292061855)
# ('krome_idx_CHj', 1.8295045085602581)

# %%
test1,test2,Name,species_list = initial('case5','case5_1')
alpha(test1,test2,Name,species_list,1,1.2)
# Out:
# < -0.375
# ('krome_idx_MG', -0.5774166741201894)
# ('krome_idx_HCO', -0.4278104403531203)
# < -0.125
# ('krome_idx_N2', -0.16205267598127915)
# < 0.125
# ('krome_idx_CO', -0.028529387472110188)
# ('krome_idx_O2', -0.022275345153546428)
# ('krome_idx_H2', -0.0005487613635272545)
# ('krome_idx_HE', -0.0)
# ('krome_idx_O', 0.041660844062130796)
# ('krome_idx_MGj', 0.0757929999562648)
# < 0.375
# ('krome_idx_E', 0.1523148739721982)
# ('krome_idx_H2O', 0.24479751167459998)
# ('krome_idx_CO2', 0.32253554359415193)
# ('krome_idx_N', 0.33965927231045895)
# ('krome_idx_NH3', 0.3425963044928209)
# ('krome_idx_NO', 0.36351588314794137)
# < 0.625
# ('krome_idx_CH', 0.42148899625406816)
# ('krome_idx_CH2', 0.5485381045536186)
# ('krome_idx_O2j', 0.5729509716004336)
# ('krome_idx_N2Hj', 0.5977599391375789)
# < 0.875
# ('krome_idx_NH', 0.6410198816404218)
# ('krome_idx_HCOj', 0.7021853934921966)
# ('krome_idx_Hj', 0.7090068817975803)
# ('krome_idx_HCN', 0.7618771243966133)
# ('krome_idx_N2j', 0.790191244857149)
# ('krome_idx_Cj', 0.813996225291775)
# ('krome_idx_OH', 0.8153755736945097)
# < 1.125
# ('krome_idx_H3j', 0.8857527237502691)
# ('krome_idx_COj', 0.9033525742920504)
# ('krome_idx_H3Oj', 0.9153426489207778)
# ('krome_idx_HEj', 0.9496979368984078)
# ('krome_idx_C', 0.9632260709157394)
# ('krome_idx_H2j', 0.9782644819789028)
# ('krome_idx_Oj', 0.990445734589234)
# ('krome_idx_OHj', 0.9916929110068784)
# ('krome_idx_H', 0.9983904747425302)
# ('krome_idx_CN', 1.0341515082356452)
# ('krome_idx_Nj', 1.0428894842243748)
# ('krome_idx_H2Oj', 1.0626290610741655)
# ('krome_idx_NH2', 1.0815321898723673)
# ('krome_idx_NH3j', 1.100977758308737)
# ('krome_idx_NHj', 1.10170975034499)
# ('krome_idx_HNOj', 1.1026184139405868)
# < 1.375
# ('krome_idx_C2H2j', 1.1996695225478784)
# ('krome_idx_NH2j', 1.2209870831892153)
# ('krome_idx_C2j', 1.2602085442116844)
# ('krome_idx_C2Hj', 1.288814890198669)
# ('krome_idx_C2', 1.3070408771045412)
# ('krome_idx_CH3j', 1.3631259803437035)
# < 1.625
# ('krome_idx_HCNHj', 1.460308801363486)
# ('krome_idx_CH2j', 1.514701729646449)
# < 1.875
# ('krome_idx_HCNj', 1.636062845480241)
# ('krome_idx_CHj', 1.6772867240289406)

# %%
import matplotlib.pyplot as plt 
def alpha_range(krolik_table,txt1,txt2,zeta1,zeta2):
    test1,test2,Name,species_list = initial(txt1,txt2)
    user_alpha = {}
    for i in species_list:
        temp = log_dev(test1[eval(i)], test2[eval(i)],zeta1,zeta2)
        temp_dic = {i:temp}
        user_alpha.update(temp_dic)
    krolik_range = {}
    data1 = open(krolik_table)
    title = ''
    while 1:
        line = data1.readline()
        if not line:
            break
        if line[0]=='#':
            title = line[1:-1]
            continue
        line = line.strip('\n').upper()
        line = line.replace('+','j')
        alpha = float(line[0:line.find(' ')])
        temp = line[line.find(' '):-1]
        temp = temp.replace(' ','')
        temp_list = temp.split(',')
        for i in temp_list:
            temp_dic = {i:alpha}
            krolik_range.update(temp_dic)
    me = [] # Store my calculation
    krolik = [] #Store the range of alpha
    names = []
    for key in krolik_range:
        temp = 'krome_idx_'+key
        me.append(user_alpha[temp]) #My Calculation
        krolik.append(krolik_range[key]) #Krolik's Results
        names.append(key.replace('j','+'))
    me, krolik = np.array(me), np.array(krolik)
    i = np.arange(len(krolik_range))
    plt.figure(figsize=(30,15))
    plt.title(title,fontsize=30)
    plt.fill_between(i, krolik, krolik+0.25, alpha=0.5, edgecolor='#89916B', facecolor='#B5CAA0')
    for j in range(len(me)):
        col = '#CC543A' #Color of the dot
        if ((krolik[j]-0.25<me[j]) and (me[j]<krolik[j]+0.50)):
            col = '#86A697'
        else:
            plt.text(i[j]-0.15*(len(names[j])-1),me[j]-0.125,names[j],fontsize=15)
        plt.scatter(i[j],me[j],color=col)
    plt.xticks(i, names,fontsize=20, rotation=60)
    plt.yticks(fontsize=30)
    plt.ylabel(r'$\alpha$',fontsize=30)
    plt.savefig(krolik_table+'.png')
    plt.show()

# %%
# Cosmic Ray 6.8e-18
alpha_range('Table1','case1','case1_1',6.8,7.8)

# %%
# Cosmic Ray 6.8e-16
alpha_range('Table2','case2','case2_1',6.8,7.8)

# %%
# X-ray Jx21=0.08
alpha_range('Table3','case3','case3_1',1,1.2)

# %%
# X-ray Jx21=8
alpha_range('Table4','case4','case4_1',1,1.2)

# %%
# X-ray Jx21=80
alpha_range('Table4','case4','case4_1',1,1.2)
